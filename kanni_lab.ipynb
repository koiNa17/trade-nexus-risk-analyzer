# %%
import yfinance as yf
import pandas as pd

df = yf.download("JPY=X", period="1mo")
df.columns = df.columns.droplevel(1)

df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open  Volume
# Date
# 2026-01-05  156.988998  157.292007  156.315002  156.966003       0
# 2026-01-06  156.626007  156.783005  156.158997  156.585999       0
# 2026-01-07  156.679993  156.794006  156.298996  156.656998       0
# 2026-01-08  156.731003  157.059998  156.466995  156.692993       0
# 2026-01-09  156.880005  158.160995  156.884995  156.895996       0
